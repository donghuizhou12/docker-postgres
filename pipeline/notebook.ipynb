# %%
import pandas as pd

# %%
pd.__file__
# Out:
# '/workspaces/docker-postgres/pipeline/.venv/lib/python3.13/site-packages/pandas/__init__.py'

# %%
import requests, io
prefix = "https://d37ci6vzurychx.cloudfront.net/trip-data"
url = f"{prefix}/yellow_tripdata_2021-01.parquet"

import pyarrow.parquet as pq

# table = pq.read_table(url)
# df2 = table.to_pandas()

# prefix="https://d37ci6vzurychx.cloudfront.net/trip-data/"
# url=f'{prefix}/yellow_tripdata_2021-01.parquet'
# resp = requests.get(url)
# resp.raise_for_status()   # ensure no 403/404

# df = pd.read_parquet(io.BytesIO(resp.content))
# df.head()

# %%
prefix="https://d37ci6vzurychx.cloudfront.net/trip-data"
url=f'{prefix}/yellow_tripdata_2021-01.parquet'
df = pd.read_parquet(url)
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
# Out:
# "Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',\n       'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',\n       'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',\n       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',\n       'total_amount', 'congestion_surcharge', 'airport_fee'],\n      dtype='str')"

# %%
len(df)
# Out:
# 1369769

# %%
df.VendorID
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#           ..
# 1369764    2
# 1369765    2
# 1369766    2
# 1369767    6
# 1369768    2
# Name: VendorID, Length: 1369769, dtype: int64

# %%
df.tpep_pickup_datetime
# Out:
# 0         2021-01-01 00:30:10
# 1         2021-01-01 00:51:20
# 2         2021-01-01 00:43:30
# 3         2021-01-01 00:15:48
# 4         2021-01-01 00:31:49
#                   ...
# 1369764   2021-01-31 23:03:00
# 1369765   2021-01-31 23:29:00
# 1369766   2021-01-31 23:25:00
# 1369767   2021-01-31 23:01:06
# 1369768   2021-01-31 23:08:29
# Name: tpep_pickup_datetime, Length: 1369769, dtype: datetime64[us]

# %%
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/'
url = f'{prefix}/yellow_tripdata_2021-01.csv.gz'
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    url,
    # nrows=100,
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
import requests, io
prefix = "https://d37ci6vzurychx.cloudfront.net/trip-data"
url = f"{prefix}/yellow_tripdata_2021-01.parquet"
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]
df2= pd.read_parquet(url)
df2=df2.astype(dtype)
for col in parse_dates:
    df2[col]=pd.to_datetime(df2[col])

df2.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df2.tpep_pickup_datetime
# Out:
# 0         2021-01-01 00:30:10
# 1         2021-01-01 00:51:20
# 2         2021-01-01 00:43:30
# 3         2021-01-01 00:15:48
# 4         2021-01-01 00:31:49
#                   ...
# 1369764   2021-01-31 23:03:00
# 1369765   2021-01-31 23:29:00
# 1369766   2021-01-31 23:25:00
# 1369767   2021-01-31 23:01:06
# 1369768   2021-01-31 23:08:29
# Name: tpep_pickup_datetime, Length: 1369769, dtype: datetime64[us]

# %%
df.tpep_pickup_datetime
max_length=len(df)
max_length
# Out:
# 1369769

# %%
from sqlalchemy import create_engine
engine=create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df2, name='yellow_taxi_data',con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df2.head(0).to_sql(
    name='yellow_taxi_data',
    con=engine,
    schema='golden',
    if_exists='replace',   # or 'append'
    # index=False
)
# Out:
# 0

# %%
df.head(0).to_sql(
    name='yellow_taxi_data',
    con=engine,
    # schema='golden',
    if_exists='replace',   # or 'append'
    # index=False
)
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.head(0).to_sql(
#       2     name='yellow_taxi_data',
#       3     con=engine,
#       4     # schema='golden',
#
# File /workspaces/docker-postgres/pipeline/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3048         3
#    3049         """  # noqa: E501
#    3050         from pandas.io import sql
#    3051
# -> 3052         return sql.to_sql(
#    3053             self,
#    3054             name,
#    3055             con,
#
# File /workspaces/docker-postgres/pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:840, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
# ...

# %%
from sqlalchemy import create_engine, text

engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")

with engine.connect() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS golden"))
    conn.commit()


# Create empty table structure
df.head(0).to_sql(
    name='yellow_taxi_data',
    con=engine,
    schema='golden',
    if_exists='replace',
    index=False
)
# Out:
# 0

# %%
df_length=len(df2)
print(df_length)
# Out:
# 1369769

# %%
df_iter=pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates,
    iterator= True,
    chunksize=100000)

# %%
def df_to_iter(df, chunksize=100000):
    for start in range(0, df_length, chunksize):
        yield df.iloc[start:start+chunksize]

df_iter = df_to_iter(df2, chunksize=100000)

df=next(df_iter)
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52                3
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45                2
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22                2
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37                2
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44                5
#
# ...

# %%
# !uv add tqdm
# Out:
# Resolved 119 packages in 1ms
# Checked 15 packages in 0.45ms

# %%
from tqdm.auto import tqdm

# %%
for chunk in tqdm(df_iter):
    chunk.to_sql(
        name='yellow_taxi_data',
        schema='golden',
        con=engine,
        if_exists='append',
        index=False
    )
# Out:
# 0it [00:00, ?it/s]

# %%
for chunk in df_iter:
    print(len(chunk))

# %%
from sqlalchemy import create_engine, text
with engine.connect() as conn:
    conn.execute(text("select * from golden.yellow_taxi_data"))
    conn.commit()

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM golden.yellow_taxi_data LIMIT 5"))
    rows = result.fetchall()

for row in rows:
    print(row)
